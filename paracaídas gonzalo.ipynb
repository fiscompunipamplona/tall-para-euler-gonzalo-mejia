# %%
from pylab import plot, show
from math import exp

vnum=[]
time=[]
vana=[]

dt=1
g=9.8
m=68.1
c=12.5
vi=0

for t in range (21):
    
    vi=vi+((c/m)*vi-g)*dt
    v=(m*g/c)*(-exp(c*t/m)+1)
    
    vnum.append (vi)
    time.append (t)
    vana.append (v)
    
print(vnum) 
print(vana)

plot (time,vnum)
plot (time,vana)
show
# Out:
# [-9.8, -21.398825256975037, -35.126656618387486, -51.37428081412675, -70.60421488426749, -93.36387253556475, -120.30114723005167, -152.18285560561182, -189.91656625275056, -234.57643524187512, -287.4337838545541, -349.9932889673577, -424.03581631085217, -511.66911592738154, -615.3878229625103, -738.1444718175967, -883.433545205555, -1055.3909507131825, -1258.9117566443833, -1499.7895387009883, -1784.8813042481593]
# [0.0, -10.757063630516617, -23.68145355847592, -39.209841299537686, -57.86687866693556, -80.28292398553863, -107.21533977218009, -139.57408145899151, -178.4524417163414, -225.1639891222885, -281.2869492115207, -348.71752738963824, -429.73397531408705, -527.0735653285319, -644.0250736570147, -784.5398970528946, -953.3655571591249, -1156.2061032416107, -1399.9148327626565, -1692.7258411722328, -2044.5322242030436]
# <function matplotlib.pyplot.show(*args, **kw)>
